# %% [markdown]
# # Lab: Week #5 | Measurements in Qiskit
# ---
#
# In this week's lab, we will create and simulate quantum circuits involving measurements using Qiskit.
#
# ---

# %% [markdown]
# ## **Part 0: Importing from Qiskit**
# ---
#
# Run the cell directly below before doing anything else. This will import all of the functions that we will use today.

# %%
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit  #Importing the QuantumCircuit function from Qiskit. We will use this to create our quantum circuits!

# We will use these functions to run our circuit and visualize its final state
from qiskit import Aer, execute 
from qiskit.visualization import *

import warnings  # We are using this library to suppress some warning messages
warnings.filterwarnings("ignore")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## **Part 1: Qiskit Review**
# ---

# %% [markdown]
# #### **Exercise #1**
#
# **Together**, let's create and draw a 1-qubit circuit with 1 X gate.

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.draw()

# %% [markdown]
# #### **Exercise #2**
#
# **Together**, let's create and run a 1-qubit circuit with 1 H gate using `visualize_transition`. While we wait for this to load, let's continue on to the next problem.

# %%
qc = QuantumCircuit(1)
qc.h(0)
visualize_transition(qc, trace = True, fpg = 10)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img6f15f7cc6796405c935952fb8ea62ce9">
#   <div class="anim-controls">
#     <input id="_anim_slider6f15f7cc6796405c935952fb8ea62ce9" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim6f15f7cc6796405c935952fb8ea62ce9.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim6f15f7cc6796405c935952fb8ea62ce9.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select6f15f7cc6796405c935952fb8ea62ce9"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_6f15f7cc6796405c935952fb8ea62ce9"
#              checked>
#       <label for="_anim_radio1_6f15f7cc6796405c935952fb8ea62ce9">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_6f15f7cc6796405c935952fb8ea62ce9"
#              >
#       <label for="_anim_radio2_6f15f7cc6796405c935952fb8ea62ce9">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_6f15f7cc6796405c935952fb8ea62ce9"
#              >
#       <label for="_anim_radio3_6f15f7cc6796405c935952fb8ea62ce9">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6f15f7cc6796405c935952fb8ea62ce9";
#     var slider_id = "_anim_slider6f15f7cc6796405c935952fb8ea62ce9";
#     var loop_select_id = "_anim_loop_select6f15f7cc6796405c935952fb8ea62ce9";
#     var frames = new Array(11);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# #### **Exercise #3**
#
# **Together**, let's create and draw a 1-qubit circuit with 1 X gate applied first and then 1 H gate.

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.h(0)
qc.draw()

# %% [markdown]
# #### **Exercise #4**
# Create and run a 1-qubit circuit with 1 H gate applied first and then 1 X gate using `visualize_transition`. While this loads, continue onto the next problems in this section.

# %%
qc = QuantumCircuit(1)
qc.h(0)
qc.x(0)
visualize_transition(qc, trace = True, fpg = 10)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img760ca7e403044b51b74ba6b062b06aec">
#   <div class="anim-controls">
#     <input id="_anim_slider760ca7e403044b51b74ba6b062b06aec" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim760ca7e403044b51b74ba6b062b06aec.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim760ca7e403044b51b74ba6b062b06aec.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim760ca7e403044b51b74ba6b062b06aec.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim760ca7e403044b51b74ba6b062b06aec.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim760ca7e403044b51b74ba6b062b06aec.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim760ca7e403044b51b74ba6b062b06aec.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim760ca7e403044b51b74ba6b062b06aec.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim760ca7e403044b51b74ba6b062b06aec.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim760ca7e403044b51b74ba6b062b06aec.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim760ca7e403044b51b74ba6b062b06aec.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select760ca7e403044b51b74ba6b062b06aec"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_760ca7e403044b51b74ba6b062b06aec"
#              checked>
#       <label for="_anim_radio1_760ca7e403044b51b74ba6b062b06aec">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_760ca7e403044b51b74ba6b062b06aec"
#              >
#       <label for="_anim_radio2_760ca7e403044b51b74ba6b062b06aec">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_760ca7e403044b51b74ba6b062b06aec"
#              >
#       <label for="_anim_radio3_760ca7e403044b51b74ba6b062b06aec">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img760ca7e403044b51b74ba6b062b06aec";
#     var slider_id = "_anim_slider760ca7e403044b51b74ba6b062b06aec";
#     var loop_select_id = "_anim_loop_select760ca7e403044b51b74ba6b062b06aec";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjUuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/YYfK9AAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# #### **Exercise #5**
# Create and draw a 1-qubit circuit with 1 X gate applied first and then 3 H gates.

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.h(0)
qc.h(0)
qc.h(0)
qc.draw()

# %% [markdown]
# #### **Exercise #6**
# Create and draw a 1-qubit circuit with gates applied in this order: X, H, X, X, H, X

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.h(0)
qc.x(0)
qc.x(0)
qc.h(0)
qc.x(0)
qc.draw()

# %% [markdown]
# ## **Part 2: Measurement in Qiskit**
# ---

# %% [markdown]
# #### **Exercise #1**
# **Together**, let's create and draw an empty quantum circuit with 1 qubit and 1 classical bit.

# %%
qc = QuantumCircuit(1,1)
qc.measure(0,0)
qc.draw()

# %% [markdown]
# #### **Exercise #2**
# Together, let's create an empty quantum circuit with 1 qubit and 1 classical bit. Then we will measure the qubit's state and store the result in our classical bit. And lastly, we will draw this circuit.

# %%
qc = QuantumCircuit(1,1)
qc.measure(0,0)
qc.draw()

# %% [markdown]
# #### **Exercise #3**
# Together, let's do the same as in #2, but let's also apply an X gate to the qubit before measuring.

# %%
qc = QuantumCircuit(1,1)
qc.x(0)
qc.measure(0,0)
qc.draw()

# %% [markdown]
# #### **Exercise #4**
# Now, create a 1-qubit/1-classical bit quantum circuit where you apply an H gate to the qubit and then measure. Draw this circuit.

# %%
qc = QuantumCircuit(1,1)
qc.h(0)
qc.measure(0,0)
qc.draw()

# %% [markdown]
# #### **Exercise #5**
# Now, create a 1-qubit/1-classical bit quantum circuit where you apply 2 H gates first and 1 X gate to the qubit and then measure. Draw this circuit.

# %%
qc = QuantumCircuit(1,1)
qc.h(0)
qc.h(0)
qc.x(0)
qc.measure(0,0)
qc.draw()

# %% [markdown]
# ## **Part 3: QASM Simulator**
# ---

# %% [markdown]
# #### **Exercise #1**
# **Together**, let's simulate a circuit using QASM where we apply no gates and measure.

# %%
# Circuit
qc = QuantumCircuit(1, 1)

qc.measure(0, 0)


# Simulate using QASM
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend, shots = 1024)  # Make sure you change "qc" to the name of your quantum circuit in this line!
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# #### **Exercise #2**
# **Together**, let's simulate a circuit using QASM where we apply 1 H gate and measure.
#
# **Before running, what do you expect to happen?**

# %%
# Circuit
qc = QuantumCircuit(1, 1)

qc.h(0)

qc.measure(0, 0)


# Simulate using QASM
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend, shots = 1000024)  # Make sure you change "qc" to the name of your quantum circuit in this line!
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# **After running,** what did you notice?
#
# Let's try running it again to see if we get the same results!

# %% [markdown]
# #### **Exercise #3**
# Simulate a circuit using QASM where you apply 1 X gate and measure.

# %%
# Circuit
# Complete this part
qc = QuantumCircuit(1,1)
qc.x(0)
qc.x(0)
qc.measure(0,0)

# Simulate using QASM
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend, shots = 1024)  # Make sure you change "qc" to the name of your quantum circuit in this line!
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# #### **Exercise #4**
# Simulate a circuit using QASM where you apply 1 H gate and 1 X gate and measure.

# %%
# Circuit
# Complete this part
qc = QuantumCircuit(1,1)
qc.h(0)
qc.x(0)
qc.measure(0,0)


# Simulate using QASM
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend, shots = 1000024)  # Make sure you change "qc" to the name of your quantum circuit in this line!
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# #### **Exercise #5**
# Simulate a circuit using QASM where you apply 1 X gate and 1 H gate and measure. NOTE: This is the reverse of #4.

# %%
# Circuit
# Complete this part
qc = QuantumCircuit(1,1)
qc.x(0)
qc.h(0)
qc.measure(0,0)


# Simulate using QASM
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend, shots = 1000024)  # Make sure you change "qc" to the name of your quantum circuit in this line!
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# #### **Exercise #6**
# Simulate a circuit using QASM where you apply 2 H gates and measure.

# %%
# Circuit
# Complete this part
qc = QuantumCircuit(1,1)
qc.h(0)
qc.h(0)
qc.measure(0,0)

# Simulate using QASM
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend = backend, shots = 1024)  # Make sure you change "qc" to the name of your quantum circuit in this line!
result = job.result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# ---
# # © 2022 The Coding School, All rights reserved
